# %%
print("Hello, world")
# Out:
# Hello, world

# %%
print("Mom: We have to do shopping for dinner")
print("Dad: Ok, what should I buy in the supermarket?")
print("Mom: We need eggs, butter, sugar, salt, flour, milk, bananas for making a piece cake")
print("Dad: Can you tell me the exact quantity of items?")
print("Mom: Yes, of course")
# Out:
# Mom: We have to do shopping for dinner
# Dad: Ok, what should I buy in the supermarket?
# Mom: We need eggs, butter, sugar, salt, flour, milk, bananas for making a piece cake
# Dad: Can you tell me the exact quantity of items?
# Mom: Yes, of course

# %%
print("Dad: How many grams of butter is needed?", end=' ')
butter = input()
print("Dad: How many eggs is needed?", end=' ')
eggs = input()
print("Dad: How many bananas is needed?", end=' ')
bananas = input()
print("Dad: How many grams of sugar is needed?", end=' ')
sugar = input()
print("Dad: How many grams of salt is needed?", end=' ')
salt = input()
print("Dad: How many grams of flour is needed?", end=' ')
flour = input()
print("Dad: How many ml of milk is needed?", end=' ')
milk = input()
print(f"Dad: To sum up, I have to buy {butter} grams of butter, {eggs} eggs, {bananas} bananas, {sugar} grams of sugar, {salt} grams of salt, {flour} grams of salt and {milk} ml of milk.")
# Out:
# Dad: How many grams of butter is needed?
#  200
# Dad: How many eggs is needed?
#  5
# Dad: How many bananas is needed?
#  5
# Dad: How many grams of sugar is needed?
#  200
# Dad: How many grams of salt is needed?
#  100
# Dad: How many grams of flour is needed?
#  1000
# Dad: How many ml of milk is needed?
#  1000
# Dad: To sum up, I have to buy 200 grams of butter, 5 eggs, 5 bananas, 200 grams of sugar, 100 grams of salt, 1000 grams of salt and 1000 ml of milk.
